# %%
import pandas as pd
import numpy as np

# %%
tree=pd.read_csv('/content/drive/MyDrive/employee.csv')

# %%
tree.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
tree.shape
# Out:
# (1470, 35)

# %%
tree.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
tree.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
print(tree.EmployeeCount.unique())
print(tree.EmployeeNumber.unique())
print(tree.Over18.unique())
print(tree.StandardHours.unique())
# Out:
# [1]
# [   1    2    4 ... 2064 2065 2068]
# ['Y']
# [80]

# %%
tree=tree.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)

# %%
tree.shape
# Out:
# (1470, 31)

# %%
tree.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
tree['Attrition']=np.where(tree['Attrition']=='Yes',1,0)

# %%
tree.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
tree.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
tree_dummies=pd.get_dummies(tree[['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus',
                                  'OverTime']])

# %%
tree_dummies.head()
# Out:
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                      False                             False
# 1                      False                              True
# 2                      False                             False
# 3                      False                              True
# 4                      False                             False
#
#    BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                          True                       False
# 1                         False                       False
# 2                          True                       False
# 3                         False                       False
# 4                          True                       False
#
#    Department_Research & Development  Department_Sales  \
# 0                              False              True
# 1                               True             False
# ...

# %%
tree_dummies.shape
# Out:
# (1470, 28)

# %%
tree.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
tree_duplicate=tree.copy()

# %%
tree_duplicate.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Manufacturing Director  \
# 0                4  ...                           False
# 1                2  ...                           False
# ...

# %%
tree=tree.drop(['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus',
                                  'OverTime'],axis=1)

# %%
tree=pd.concat([tree,tree_dummies],axis=1)

# %%
tree.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Manufacturing Director  \
# 0                4  ...                           False
# 1                2  ...                           False
# ...

# %%
x=tree.drop(['Attrition'],axis=1)
y=tree['Attrition']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 714    50       1126                 1          2                        4
# 135    36        216                 6          2                        2
# 1271   21        337                 7          1                        2
# 477    50       1246                 3          3                        1
# 806    52        994                 7          4                        2
# ...   ...        ...               ...        ...                      ...
# 1130   35        750                28          3                        2
# 1294   41        447                 5          3                        2
# 860    22       1256                 3          4                        3
# 1459   29       1378                13          2                        4
# 1126   50        264                 9          3                        3
#
# ...

# %% [markdown]
# # Model-1

# %%
from sklearn import tree
dt1=tree.DecisionTreeClassifier()
dt1.fit(X_train,y_train)
y_pred1=dt1.predict(X_test)

# %% [markdown]
# # Model-2

# %%
dt2=tree.DecisionTreeClassifier(criterion='entropy',max_depth=4)
dt2.fit(X_train,y_train)
y_pred2=dt2.predict(X_test)

# %% [markdown]
# # Model-3

# %%
dt3=tree.DecisionTreeClassifier(criterion='entropy',max_depth=2,min_samples_leaf=2)
dt3.fit(X_train,y_train)
y_pred3=dt3.predict(X_test)

# %%
from sklearn import metrics
print('Accuracy M1:',metrics.accuracy_score(y_test,y_pred1))
print('Accuracy M2:',metrics.accuracy_score(y_test,y_pred2))
print('Accuracy M3:',metrics.accuracy_score(y_test,y_pred3))
# Out:
# Accuracy M1: 0.8027210884353742
# Accuracy M2: 0.8594104308390023
# Accuracy M3: 0.8616780045351474

# %%
from sklearn.model_selection import GridSearchCV
param_grid={"max_depth":[2,3,4,5],
            "max_features":[1,3,5,10],
            "min_samples_split":[2,3,5,10],
            "criterion":["gini","entropy"],
            "min_samples_leaf":[1,2,3,4]}
grid_search=GridSearchCV(dt1,param_grid,cv=5)
grid_search.fit(X_train,y_train)
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 3,
#  'max_features': 5,
#  'min_samples_leaf': 3,
#  'min_samples_split': 3}

# %% [markdown]
# # Model-4

# %%
dt4=tree.DecisionTreeClassifier(criterion='entropy',max_depth=3,min_samples_leaf=3,max_features=5,min_samples_split=3)
dt4.fit(X_train,y_train)
y_pred4=dt4.predict(X_test)

# %%
print('Accuracy M4:',metrics.accuracy_score(y_test,y_pred4))
# Out:
# Accuracy M4: 0.8526077097505669

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print("confusion Matrix",confusion_matrix(y_test,y_pred4))
# Out:
# confusion Matrix [[370  10]
#  [ 55   6]]

# %%
print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       380
#            1       0.38      0.10      0.16        61
#
#     accuracy                           0.85       441
#    macro avg       0.62      0.54      0.54       441
# weighted avg       0.80      0.85      0.81       441

# %% [markdown]
# # Design the decision Tree

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(40,20))
plot_tree(dt3,class_names=['No','Yes'],feature_names=x.columns,filled=True)
plt.show()

# %%
plt.figure(figsize=(40,20))
plot_tree(dt4,class_names=['No','Yes'],feature_names=x.columns,filled=True)
plt.show()

# %%
plt.figure(figsize=(40,20))
plot_tree(dt2,class_names=['No','Yes'],feature_names=x.columns,filled=True)
plt.show()

# %%
plt.figure(figsize=(40,20))
plot_tree(dt1,class_names=['No','Yes'],feature_names=x.columns,filled=True)
plt.show()
